# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files
uploaded = files.upload()

# Use the uploaded filename to read the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files
uploaded = files.upload()

# Use the uploaded filename to read the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files
uploaded = files.upload()

# Use the uploaded filename to read the data
# The key of the uploaded dictionary is the filename
filename = list(uploaded.keys())[0]
df = pd.read_csv(filename)

# Display basic dataset information
print("Dataset Shape:", df.shape)
print("Missing Values:\n", df.isnull().sum())

df.head()

print("Dataset Shape:", df.shape)
print("Missing Values:\n", df.isnull().sum())

df.head()

print("Dataset Shape:", df.shape)
print("Missing Values:\n", df.isnull().sum())

df.head()

print("Dataset Shape:", df.shape)
print("Missing Values:\n", df.isnull().sum())

df.head()
# Out:
#      <input type="file" id="files-94bac0e3-ff29-4fb8-a22e-9d54e55eb5f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94bac0e3-ff29-4fb8-a22e-9d54e55eb5f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Creating  a correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_cleaned.corr(numeric_only=True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
# worst top 10 hotels according to the reviewer score
plt.figure(figsize=(12, 5))
sns.barplot(y=top_10_worst["Hotel_Name"], x=top_10_worst["Reviewer_Score"], hue=top_10_worst["Hotel_Name"], palette="Reds_r", legend=False)
plt.title("Worst 10 Hotels Based on Reviewer Score")
plt.xlabel("Reviewer Score")
plt.ylabel("Hotel Name")
plt.show()

# %%
# top best hotel according to the reviewer score.
plt.figure(figsize=(12, 5))
sns.barplot(y=top_10_best["Hotel_Name"], x=top_10_best["Reviewer_Score"], hue=top_10_best["Hotel_Name"], palette="Greens", legend=False)
plt.title("Best 10 Hotels Based on Reviewer Score")
plt.xlabel("Reviewer Score")
plt.ylabel("Hotel Name")
plt.show()
